# %%
import torch
import matplotlib.pyplot as plt
from generate import generate

# %%
# model = torch.load('./model/aae.pt')

# gen_results = []
# for _ in range(10):
#     gen_results.append(generate(model.decoder, 28))

# %%
model = torch.load('./model/cvae.pt')
CONDITION = 2

gen_results = []
for _ in range(10):
    gen_results.append(generate(model.decoder, 28, CONDITION))

# %%
_ = plt.figure(figsize=(20, 8))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(gen_results[i])
plt.show()
